# %%
import gym
env = gym.make("LunarLander-v2", render_mode="human")
env.action_space.seed(42)

observation, info = env.reset(seed=42)

for _ in range(1000):
    observation, reward, terminated, truncated, info = env.step(env.action_space.sample())

    if terminated or truncated:
        observation, info = env.reset()

env.close()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File D:\softwares\Anaconda\Anacondanew\lib\site-packages\gym\envs\box2d\bipedal_walker.py:14, in <module>
#      13 try:
# ---> 14     import Box2D
#      15     from Box2D.b2 import (
#      16         circleShape,
#      17         contactListener,
#    (...)
#      21         revoluteJointDef,
#      22     )
#
# ModuleNotFoundError: No module named 'Box2D'
#
# During handling of the above exception, another exception occurred:
#
# DependencyNotInstalled                    Traceback (most recent call last)
# Input In [1], in <cell line: 2>()
#       1 import gym
# ----> 2 env = gym.make("LunarLander-v2", render_mode="human")
#       3 env.action_space.seed(42)
#       5 observation, info = env.reset(seed=42)
#
# File D:\softwares\Anaconda\Anacondanew\lib\site-packages\gym\envs\registration.py:581, in make(id, max_episode_steps, autoreset, apply_api_compatibility, disable_env_checker, **kwargs)
#     578     env_creator = spec_.entry_point
#     579 else:
#     580     # Assume it's a string
# --> 581     env_creator = load(spec_.entry_point)
#     583 mode = _kwargs.get("render_mode")
#     584 apply_human_rendering = False
#
# File D:\softwares\Anaconda\Anacondanew\lib\site-packages\gym\envs\registration.py:61, in load(name)
#      52 """Loads an environment with name and returns an environment creation function
#      53
#      54 Args:
#    (...)
#      58     Calls the environment constructor
#      59 """
#      60 mod_name, attr_name = name.split(":")
# ---> 61 mod = importlib.import_module(mod_name)
#      62 fn = getattr(mod, attr_name)
#      63 return fn
#
# File D:\softwares\Anaconda\Anacondanew\lib\importlib\__init__.py:127, in import_module(name, package)
#     125             break
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1030, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:972, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:228, in _call_with_frames_removed(f, *args, **kwds)
#
# File <frozen importlib._bootstrap>:1030, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:986, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:680, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:850, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:228, in _call_with_frames_removed(f, *args, **kwds)
#
# File D:\softwares\Anaconda\Anacondanew\lib\site-packages\gym\envs\box2d\__init__.py:1, in <module>
# ----> 1 from gym.envs.box2d.bipedal_walker import BipedalWalker, BipedalWalkerHardcore
#       2 from gym.envs.box2d.car_racing import CarRacing
#       3 from gym.envs.box2d.lunar_lander import LunarLander, LunarLanderContinuous
#
# File D:\softwares\Anaconda\Anacondanew\lib\site-packages\gym\envs\box2d\bipedal_walker.py:24, in <module>
#      15     from Box2D.b2 import (
#      16         circleShape,
#      17         contactListener,
#    (...)
#      21         revoluteJointDef,
#      22     )
#      23 except ImportError:
# ---> 24     raise DependencyNotInstalled("box2D is not installed, run `pip install gym[box2d]`")
#      27 if TYPE_CHECKING:
#      28     import pygame
#
# DependencyNotInstalled: box2D is not installed, run `pip install gym[box2d]`

# %%
pip install gym[box2d]
# Out:
# Requirement already satisfied: gym[box2d] in d:\softwares\anaconda\anacondanew\lib\site-packages (0.26.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in d:\softwares\anaconda\anacondanew\lib\site-packages (from gym[box2d]) (2.0.0)
# Requirement already satisfied: numpy>=1.18.0 in d:\softwares\anaconda\anacondanew\lib\site-packages (from gym[box2d]) (1.21.5)
# Requirement already satisfied: importlib-metadata>=4.8.0 in d:\softwares\anaconda\anacondanew\lib\site-packages (from gym[box2d]) (4.11.3)
# Requirement already satisfied: gym-notices>=0.0.4 in d:\softwares\anaconda\anacondanew\lib\site-packages (from gym[box2d]) (0.0.8)
# Collecting swig==4.*
#   Using cached swig-4.0.2-py2.py3-none-win_amd64.whl (2.3 MB)
# Collecting box2d-py==2.3.5
#   Using cached box2d-py-2.3.5.tar.gz (374 kB)
# Requirement already satisfied: pygame==2.1.0 in d:\softwares\anaconda\anacondanew\lib\site-packages (from gym[box2d]) (2.1.0)
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: zipp>=0.5 in d:\softwares\anaconda\anacondanew\lib\site-packages (from importlib-metadata>=4.8.0->gym[box2d]) (3.7.0)
# Building wheels for collected packages: box2d-py
#   ERROR: Command errored out with exit status 1:
#    command: 'D:\softwares\Anaconda\Anacondanew\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\vamsi krishna\\AppData\\Local\\Temp\\pip-install-gk7wpxpp\\box2d-py_519c91d4050447d69968a444701d1236\\setup.py'"'"'; __file__='"'"'C:\\Users\\vamsi krishna\\AppData\\Local\\Temp\\pip-install-gk7wpxpp\\box2d-py_519c91d4050447d69968a444701d1236\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\vamsi krishna\AppData\Local\Temp\pip-wheel-tbgjuz08'
#        cwd: C:\Users\vamsi krishna\AppData\Local\Temp\pip-install-gk7wpxpp\box2d-py_519c91d4050447d69968a444701d1236\
#   Complete output (16 lines):
#   Using setuptools (version 61.2.0).
#   running bdist_wheel
#   Building wheel for box2d-py (setup.py): started
#   Building wheel for box2d-py (setup.py): finished with status 'error'
#   Running setup.py clean for box2d-py
# Failed to build box2d-py
# Installing collected packages: swig, box2d-py
#     Running setup.py install for box2d-py: started
#     Running setup.py install for box2d-py: finished with status 'error'
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.9
#   creating build\lib.win-amd64-3.9\Box2D
#   copying library\Box2D\Box2D.py -> build\lib.win-amd64-3.9\Box2D
#   copying library\Box2D\__init__.py -> build\lib.win-amd64-3.9\Box2D
#   creating build\lib.win-amd64-3.9\Box2D\b2
#   copying library\Box2D\b2\__init__.py -> build\lib.win-amd64-3.9\Box2D\b2
#   running build_ext
#   building 'Box2D._Box2D' extension
#   swigging Box2D\Box2D.i to Box2D\Box2D_wrap.cpp
#   swig.exe -python -c++ -IBox2D -small -O -includeall -ignoremissing -w201 -globals b2Globals -outdir library\Box2D -keyword -w511 -D_SWIG_KWARGS -o Box2D\Box2D_wrap.cpp Box2D\Box2D.i
#   error: command 'swig.exe' failed: None
#   ----------------------------------------
#   ERROR: Failed building wheel for box2d-py
#     ERROR: Command errored out with exit status 1:
#      command: 'D:\softwares\Anaconda\Anacondanew\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\vamsi krishna\\AppData\\Local\\Temp\\pip-install-gk7wpxpp\\box2d-py_519c91d4050447d69968a444701d1236\\setup.py'"'"'; __file__='"'"'C:\\Users\\vamsi krishna\\AppData\\Local\\Temp\\pip-install-gk7wpxpp\\box2d-py_519c91d4050447d69968a444701d1236\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\vamsi krishna\AppData\Local\Temp\pip-record-hbtw_w5n\install-record.txt' --single-version-externally-managed --compile --install-headers 'D:\softwares\Anaconda\Anacondanew\Include\box2d-py'
#          cwd: C:\Users\vamsi krishna\AppData\Local\Temp\pip-install-gk7wpxpp\box2d-py_519c91d4050447d69968a444701d1236\
#     Complete output (30 lines):
#     Using setuptools (version 61.2.0).
#     running install
#     D:\softwares\Anaconda\Anacondanew\lib\site-packages\setuptools\command\install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#       warnings.warn(
#     running build
#     running build_py
#     creating build
#     creating build\lib.win-amd64-3.9
#     creating build\lib.win-amd64-3.9\Box2D
#     copying library\Box2D\Box2D.py -> build\lib.win-amd64-3.9\Box2D
#     copying library\Box2D\__init__.py -> build\lib.win-amd64-3.9\Box2D
#     creating build\lib.win-amd64-3.9\Box2D\b2
#     copying library\Box2D\b2\__init__.py -> build\lib.win-amd64-3.9\Box2D\b2
#     running build_ext
#     building 'Box2D._Box2D' extension
#     swigging Box2D\Box2D.i to Box2D\Box2D_wrap.cpp
#     swig.exe -python -c++ -IBox2D -small -O -includeall -ignoremissing -w201 -globals b2Globals -outdir library\Box2D -keyword -w511 -D_SWIG_KWARGS -o Box2D\Box2D_wrap.cpp Box2D\Box2D.i
#     Box2D\Common\b2Math.h(67) : Warning 302: Identifier 'b2Vec2' redefined by %extend (ignored),
#     Box2D\Box2D_math.i(47) : Warning 302: %extend definition of 'b2Vec2'.
#     Box2D\Common\b2Math.h(158) : Warning 302: Identifier 'b2Vec3' redefined by %extend (ignored),
#     Box2D\Box2D_math.i(168) : Warning 302: %extend definition of 'b2Vec3'.
#     Box2D\Common\b2Math.h(197) : Warning 302: Identifier 'b2Mat22' redefined by %extend (ignored),
#     Box2D\Box2D_math.i(301) : Warning 302: %extend definition of 'b2Mat22'.
#     Box2D\Common\b2Math.h(271) : Warning 302: Identifier 'b2Mat33' redefined by %extend (ignored),
#     Box2D\Box2D_math.i(372) : Warning 302: %extend definition of 'b2Mat33'.
#     Box2D\Collision\b2DynamicTree.h(44) : Warning 312: Nested union not currently supported (ignored).
#     Box2D\Common\b2Settings.h(144) : Warning 506: Can't wrap varargs with keyword arguments enabled
#     Box2D\Common\b2Math.h(91) : Warning 509: Overloaded method b2Vec2::operator ()(int32) effectively ignored,
#     Box2D\Common\b2Math.h(85) : Warning 509: as it is shadowed by b2Vec2::operator ()(int32) const.
#     error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: 'D:\softwares\Anaconda\Anacondanew\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\vamsi krishna\\AppData\\Local\\Temp\\pip-install-gk7wpxpp\\box2d-py_519c91d4050447d69968a444701d1236\\setup.py'"'"'; __file__='"'"'C:\\Users\\vamsi krishna\\AppData\\Local\\Temp\\pip-install-gk7wpxpp\\box2d-py_519c91d4050447d69968a444701d1236\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\vamsi krishna\AppData\Local\Temp\pip-record-hbtw_w5n\install-record.txt' --single-version-externally-managed --compile --install-headers 'D:\softwares\Anaconda\Anacondanew\Include\box2d-py' Check the logs for full command output.

# %%
conda install swig
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: D:\softwares\Anaconda\Anacondanew
#
#   added / updated specs:
#     - swig
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.14.0               |   py39haa95532_0         937 KB
#     swig-4.0.2                 |       hd77b12b_4         1.5 MB
#     ------------------------------------------------------------
#                                            Total:         2.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   swig               pkgs/main/win-64::swig-4.0.2-hd77b12b_4
#
# The following packages will be UPDATED:
#
#   conda                               4.12.0-py39haa95532_0 --> 4.14.0-py39haa95532_0
#
#
#
# Downloading and Extracting Packages
#
# swig-4.0.2           | 1.5 MB    |            |   0%
# swig-4.0.2           | 1.5 MB    | 1          |   1%
# swig-4.0.2           | 1.5 MB    | ########## | 100%
# swig-4.0.2           | 1.5 MB    | ########## | 100%
#
# conda-4.14.0         | 937 KB    |            |   0%
# conda-4.14.0         | 937 KB    | ########## | 100%
# conda-4.14.0         | 937 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Note: you may need to restart the kernel to use updated packages.
# Executing transaction: ...working... done

# %%
pip install gym[box2d]
# Out:
# Requirement already satisfied: gym[box2d] in d:\softwares\anaconda\anacondanew\lib\site-packages (0.26.0)
# Requirement already satisfied: numpy>=1.18.0 in d:\softwares\anaconda\anacondanew\lib\site-packages (from gym[box2d]) (1.21.5)
# Requirement already satisfied: gym-notices>=0.0.4 in d:\softwares\anaconda\anacondanew\lib\site-packages (from gym[box2d]) (0.0.8)
# Requirement already satisfied: cloudpickle>=1.2.0 in d:\softwares\anaconda\anacondanew\lib\site-packages (from gym[box2d]) (2.0.0)
# Requirement already satisfied: importlib-metadata>=4.8.0 in d:\softwares\anaconda\anacondanew\lib\site-packages (from gym[box2d]) (4.11.3)
# Requirement already satisfied: pygame==2.1.0 in d:\softwares\anaconda\anacondanew\lib\site-packages (from gym[box2d]) (2.1.0)
# Requirement already satisfied: swig==4.* in d:\softwares\anaconda\anacondanew\lib\site-packages (from gym[box2d]) (4.0.2)
# Collecting box2d-py==2.3.5
#   Using cached box2d-py-2.3.5.tar.gz (374 kB)
# Requirement already satisfied: zipp>=0.5 in d:\softwares\anaconda\anacondanew\lib\site-packages (from importlib-metadata>=4.8.0->gym[box2d]) (3.7.0)
# Building wheels for collected packages: box2d-py
#   Building wheel for box2d-py (setup.py): started
#   Building wheel for box2d-py (setup.py): finished with status 'error'
#   Running setup.py clean for box2d-py
# Failed to build box2d-py
# Installing collected packages: box2d-py
#     Running setup.py install for box2d-py: started
#     Running setup.py install for box2d-py: finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   ERROR: Command errored out with exit status 1:
#    command: 'D:\softwares\Anaconda\Anacondanew\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\vamsi krishna\\AppData\\Local\\Temp\\pip-install-uypcdi1a\\box2d-py_120c69b46a5c47639f2449d33e24bc9b\\setup.py'"'"'; __file__='"'"'C:\\Users\\vamsi krishna\\AppData\\Local\\Temp\\pip-install-uypcdi1a\\box2d-py_120c69b46a5c47639f2449d33e24bc9b\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\vamsi krishna\AppData\Local\Temp\pip-wheel-rx5d8iy8'
#        cwd: C:\Users\vamsi krishna\AppData\Local\Temp\pip-install-uypcdi1a\box2d-py_120c69b46a5c47639f2449d33e24bc9b\
#   Complete output (28 lines):
#   Using setuptools (version 61.2.0).
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.9
#   creating build\lib.win-amd64-3.9\Box2D
#   copying library\Box2D\Box2D.py -> build\lib.win-amd64-3.9\Box2D
#   copying library\Box2D\__init__.py -> build\lib.win-amd64-3.9\Box2D
#   creating build\lib.win-amd64-3.9\Box2D\b2
#   copying library\Box2D\b2\__init__.py -> build\lib.win-amd64-3.9\Box2D\b2
#   running build_ext
#   building 'Box2D._Box2D' extension
#   swigging Box2D\Box2D.i to Box2D\Box2D_wrap.cpp
#   swig.exe -python -c++ -IBox2D -small -O -includeall -ignoremissing -w201 -globals b2Globals -outdir library\Box2D -keyword -w511 -D_SWIG_KWARGS -o Box2D\Box2D_wrap.cpp Box2D\Box2D.i
#   Box2D\Common\b2Math.h(67) : Warning 302: Identifier 'b2Vec2' redefined by %extend (ignored),
#   Box2D\Box2D_math.i(47) : Warning 302: %extend definition of 'b2Vec2'.
#   Box2D\Common\b2Math.h(158) : Warning 302: Identifier 'b2Vec3' redefined by %extend (ignored),
#   Box2D\Box2D_math.i(168) : Warning 302: %extend definition of 'b2Vec3'.
#   Box2D\Common\b2Math.h(197) : Warning 302: Identifier 'b2Mat22' redefined by %extend (ignored),
#   Box2D\Box2D_math.i(301) : Warning 302: %extend definition of 'b2Mat22'.
#   Box2D\Common\b2Math.h(271) : Warning 302: Identifier 'b2Mat33' redefined by %extend (ignored),
#   Box2D\Box2D_math.i(372) : Warning 302: %extend definition of 'b2Mat33'.
#   Box2D\Collision\b2DynamicTree.h(44) : Warning 312: Nested union not currently supported (ignored).
#   Box2D\Common\b2Settings.h(144) : Warning 506: Can't wrap varargs with keyword arguments enabled
#   Box2D\Common\b2Math.h(91) : Warning 509: Overloaded method b2Vec2::operator ()(int32) effectively ignored,
#   Box2D\Common\b2Math.h(85) : Warning 509: as it is shadowed by b2Vec2::operator ()(int32) const.
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   ----------------------------------------
#   ERROR: Failed building wheel for box2d-py
#     ERROR: Command errored out with exit status 1:
#      command: 'D:\softwares\Anaconda\Anacondanew\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\vamsi krishna\\AppData\\Local\\Temp\\pip-install-uypcdi1a\\box2d-py_120c69b46a5c47639f2449d33e24bc9b\\setup.py'"'"'; __file__='"'"'C:\\Users\\vamsi krishna\\AppData\\Local\\Temp\\pip-install-uypcdi1a\\box2d-py_120c69b46a5c47639f2449d33e24bc9b\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\vamsi krishna\AppData\Local\Temp\pip-record-hu9evu5q\install-record.txt' --single-version-externally-managed --compile --install-headers 'D:\softwares\Anaconda\Anacondanew\Include\box2d-py'
#          cwd: C:\Users\vamsi krishna\AppData\Local\Temp\pip-install-uypcdi1a\box2d-py_120c69b46a5c47639f2449d33e24bc9b\
#     Complete output (30 lines):
#     Using setuptools (version 61.2.0).
#     running install
#     D:\softwares\Anaconda\Anacondanew\lib\site-packages\setuptools\command\install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#       warnings.warn(
#     running build
#     running build_py
#     creating build
#     creating build\lib.win-amd64-3.9
#     creating build\lib.win-amd64-3.9\Box2D
#     copying library\Box2D\Box2D.py -> build\lib.win-amd64-3.9\Box2D
#     copying library\Box2D\__init__.py -> build\lib.win-amd64-3.9\Box2D
#     creating build\lib.win-amd64-3.9\Box2D\b2
#     copying library\Box2D\b2\__init__.py -> build\lib.win-amd64-3.9\Box2D\b2
#     running build_ext
#     building 'Box2D._Box2D' extension
#     swigging Box2D\Box2D.i to Box2D\Box2D_wrap.cpp
#     swig.exe -python -c++ -IBox2D -small -O -includeall -ignoremissing -w201 -globals b2Globals -outdir library\Box2D -keyword -w511 -D_SWIG_KWARGS -o Box2D\Box2D_wrap.cpp Box2D\Box2D.i
#     Box2D\Common\b2Math.h(67) : Warning 302: Identifier 'b2Vec2' redefined by %extend (ignored),
#     Box2D\Box2D_math.i(47) : Warning 302: %extend definition of 'b2Vec2'.
#     Box2D\Common\b2Math.h(158) : Warning 302: Identifier 'b2Vec3' redefined by %extend (ignored),
#     Box2D\Box2D_math.i(168) : Warning 302: %extend definition of 'b2Vec3'.
#     Box2D\Common\b2Math.h(197) : Warning 302: Identifier 'b2Mat22' redefined by %extend (ignored),
#     Box2D\Box2D_math.i(301) : Warning 302: %extend definition of 'b2Mat22'.
#     Box2D\Common\b2Math.h(271) : Warning 302: Identifier 'b2Mat33' redefined by %extend (ignored),
#     Box2D\Box2D_math.i(372) : Warning 302: %extend definition of 'b2Mat33'.
#     Box2D\Collision\b2DynamicTree.h(44) : Warning 312: Nested union not currently supported (ignored).
#     Box2D\Common\b2Settings.h(144) : Warning 506: Can't wrap varargs with keyword arguments enabled
#     Box2D\Common\b2Math.h(91) : Warning 509: Overloaded method b2Vec2::operator ()(int32) effectively ignored,
#     Box2D\Common\b2Math.h(85) : Warning 509: as it is shadowed by b2Vec2::operator ()(int32) const.
#     error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: 'D:\softwares\Anaconda\Anacondanew\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\vamsi krishna\\AppData\\Local\\Temp\\pip-install-uypcdi1a\\box2d-py_120c69b46a5c47639f2449d33e24bc9b\\setup.py'"'"'; __file__='"'"'C:\\Users\\vamsi krishna\\AppData\\Local\\Temp\\pip-install-uypcdi1a\\box2d-py_120c69b46a5c47639f2449d33e24bc9b\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\vamsi krishna\AppData\Local\Temp\pip-record-hu9evu5q\install-record.txt' --single-version-externally-managed --compile --install-headers 'D:\softwares\Anaconda\Anacondanew\Include\box2d-py' Check the logs for full command output.

# %%
conda create -c conda-forge -n gymenv swig pip
